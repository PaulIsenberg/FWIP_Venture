# %%
# Import our dependencies

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
import pandas as pd
import tensorflow as tf
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from collections import Counter
from sklearn.preprocessing import LabelEncoder
from imblearn.over_sampling import RandomOverSampler
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import ClusterCentroids
from imblearn.combine import SMOTEENN
from sklearn.decomposition import PCA

# %%
# import psycopg2
# Out:
# /usr/local/lib/python3.6/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
# Connecting DB
# connection = psycopg2.connect(
   # host = 'your_RDB_AWS_instance_Endpoint',
   # port = 5432,
   # user = 'YOUR_USER_NAME',
   # password = 'YOUR_PASSWORD',
   # database='YOUR_DATABASE_NAME'
   # )
# cursor=connection.cursor()

# %%
# Reading the data into a df

# sql = """
# SELECT "table_name","column_name", "data_type", "table_schema"
# FROM INFORMATION_SCHEMA.COLUMNS
# WHERE "table_schema" = 'public'
# ORDER BY table_name  
# """
# start_ups_df = pd.read_sql(sql, con=connection)

# %%
# from google.colab import files
# data_to_load = files.upload()
# Out:
#      <input type="file" id="files-95d5099e-70dc-4beb-9f08-13bb7efe9549" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-95d5099e-70dc-4beb-9f08-13bb7efe9549">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving degrees.csv to degrees.csv

# %%
# import io
# degrees_df = pd.read_csv(io.BytesIO(data_to_load['degrees.csv']))
# degrees_df
# Out:
#             id object_id  ...           created_at           updated_at
# 0            1    p:6117  ...  2008-02-19 03:17:36  2008-02-19 03:17:36
# 1            2    p:6136  ...  2008-02-19 17:58:31  2008-02-25 00:23:55
# 2            3    p:6136  ...  2008-02-19 17:58:31  2008-02-25 00:23:55
# 3            4    p:6005  ...  2008-02-19 23:40:40  2008-02-25 00:23:55
# 4            5    p:5832  ...  2008-02-20 05:28:09  2008-02-20 05:28:09
# ...        ...       ...  ...                  ...                  ...
# 109605  109606  p:268589  ...  2013-12-12 14:28:58  2013-12-12 14:28:58
# 109606  109607  p:268527  ...  2013-12-12 14:31:21  2013-12-12 14:31:21
# 109607  109608  p:268527  ...  2013-12-12 14:31:48  2013-12-12 14:31:48
# 109608  109609  p:268528  ...  2013-12-12 14:38:15  2013-12-12 14:38:15
# 109609  109610  p:268528  ...  2013-12-12 14:38:33  2013-12-12 14:38:33
#
# [109610 rows x 8 columns]

# %%
# data_to_load = files.upload()
# Out:
#      <input type="file" id="files-0c5e46d0-e890-40bb-85cd-bdacb2276e2d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0c5e46d0-e890-40bb-85cd-bdacb2276e2d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving objects.csv to objects.csv

# %%
# objects_df = pd.read_csv(io.BytesIO(data_to_load['objects.csv']))
# objects_df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (3,7,9,10,17,18,21,22,23,25,26,29,30,37) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         id entity_type  ...           created_at           updated_at
# 0      c:1     Company  ...  2007-05-25 06:51:27  2013-04-13 03:29:00
# 1     c:10     Company  ...  2007-05-31 21:11:51  2008-05-23 23:23:14
# 2    c:100     Company  ...  2007-08-06 23:52:45  2013-11-04 02:09:48
# 3  c:10000     Company  ...  2008-08-24 16:51:57  2008-09-06 14:19:18
# 4  c:10001     Company  ...  2008-08-24 17:10:34  2008-09-06 14:19:18
#
# [5 rows x 40 columns]

# %%
# !pip install awscli

# %%
def shell(command):
  return JSON([getoutput(command)])
  output.register_callback('shell',shell)
  # !pip install boto3

# %%
import boto3
import s3fs
import awscli
import pandas as pd

# %%
# !aws configure

# %%
s3 = boto3.resource('s3')

for bucket in s3.buckets.all():
    print(bucket.name)
# Out:
# team3-final-bucket
# wshih-bucket

# %%
client = boto3.client('s3')
path = 's3://team3-final-bucket/Resources_raw/objects.csv'

# %%
objects_df = pd.read_csv(path)
objects_df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (3,7,9,10,17,18,21,22,23,25,26,29,30,37) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         id entity_type  ...           created_at           updated_at
# 0      c:1     Company  ...  2007-05-25 06:51:27  2013-04-13 03:29:00
# 1     c:10     Company  ...  2007-05-31 21:11:51  2008-05-23 23:23:14
# 2    c:100     Company  ...  2007-08-06 23:52:45  2013-11-04 02:09:48
# 3  c:10000     Company  ...  2008-08-24 16:51:57  2008-09-06 14:19:18
# 4  c:10001     Company  ...  2008-08-24 17:10:34  2008-09-06 14:19:18
#
# [5 rows x 40 columns]

# %%
# Exploring the data

# %%
# Pulling in one df all data attributes that have the same meaning but broken down to multiple tables
# such as Funding amount that has to be collected for each entity_type from different tables

# %%
# Dropping non-features columns

# %%
# Merging with other tables that have important features missing in this table

# %%
# Cleaning the data types, set all categorical columns to string, clean NANs, zeros

# %%
# Defining the target and setting lables to 0 and 1
# As we are going to predict start-up failure the "Status" column should be defined as target
# The status in this data set contains a few values: aquired, alpha, beta, closed, development, ipo, live, operating, private
# Closed status will have definition of failure, all pther statuses - non-failure
objects_df_copy = objects_df[['entity_type','category_code','status','region','funding_total_usd']].copy()

# %%
objects_df_copy.dtypes
# Out:
# entity_type           object
# category_code         object
# status                object
# region                object
# funding_total_usd    float64
# dtype: object

# %%
objects_df_copy['status'].unique()
# Out:
# array(['operating', 'acquired', 'closed', 'ipo', 'live', 'beta',
#        'private', 'alpha', 'development'], dtype=object)

# %%
objects_df_copy['status'].replace(to_replace=['closed'], value='0', inplace=True)
objects_df_copy['status'].replace(to_replace=['operating', 'acquired', 'ipo', 'live', 'beta',
       'private', 'alpha', 'development'], value='1', inplace=True)

# %%
objects_df_copy.head(20)
# Out:
#    entity_type    category_code status       region  funding_total_usd
# 0      Company              web      1      Seattle         39750000.0
# 1      Company      games_video      1  Los Angeles                0.0
# 2      Company      games_video      1       SF Bay                0.0
# 3      Company  network_hosting      1      unknown                0.0
# 4      Company      games_video      1      unknown                0.0
# 5      Company      advertising      1       Agadir                0.0
# 6      Company        cleantech      1     Vadodara                0.0
# 7      Company              NaN      1      unknown                0.0
# 8      Company      advertising      1     New York                0.0
# 9      Company       enterprise      1      unknown                0.0
# 10     Company      games_video      1      unknown                0.0
# 11     Company            other      1      unknown                0.0
# ...

# %%
objects_df_copy['status'] = pd.to_numeric(objects_df_copy['status'])
objects_df_copy.dtypes
# Out:
# entity_type           object
# category_code         object
# status                 int64
# region                object
# funding_total_usd    float64
# dtype: object

# %%
# Splitting the table to the features and the target
X_df = objects_df_copy.drop(['status','funding_total_usd'], axis=1)
y = objects_df_copy['status'].values

# %%
X_df.head()
# Out:
#   entity_type    category_code       region
# 0     Company              web      Seattle
# 1     Company      games_video  Los Angeles
# 2     Company      games_video       SF Bay
# 3     Company  network_hosting      unknown
# 4     Company      games_video      unknown

# %%
y
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
X_df.columns.to_list()
# Out:
# ['entity_type', 'category_code', 'region']

# %%
# Encode the categorical features
data_encoded_df = pd.get_dummies(X_df, columns=['entity_type', 'category_code', 'region'])
data_encoded_df
# Out:
#         entity_type_Company  ...  region_zhengzhou
# 0                         1  ...                 0
# 1                         1  ...                 0
# 2                         1  ...                 0
# 3                         1  ...                 0
# 4                         1  ...                 0
# ...                     ...  ...               ...
# 462646                    0  ...                 0
# 462647                    0  ...                 0
# 462648                    0  ...                 0
# 462649                    0  ...                 0
# 462650                    0  ...                 0
#
# [462651 rows x 6023 columns]

# %%
data_encoded_df.columns.to_list()

# %%
# Create encoded X df with the funding column added

# %%
# Splitting the data to train / test
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Scale the features 
data_scaler = StandardScaler()
X_scaled = data_scaler.fit_transform(X_df)

# %%
# Count target train data
Counter(y_train)

# %%
# Resample
smote_enn = SMOTEENN(random_state=1)
X_resampled, y_resampled = smote_enn.fit_resample(X, y)
Counter(y_resampled)

# %%
# Train
